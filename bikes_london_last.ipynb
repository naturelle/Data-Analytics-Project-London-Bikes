# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
bikes = pd.read_csv('C:/Users/Ebru/dataset/london_merged.csv')

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
bikes.season = bikes.season.astype('str')
bikes.season=bikes2.season
bikes
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# ...

# %%
bikes['timestamp'] = pd.to_datetime(bikes['timestamp'])

bikes['year'] = bikes['timestamp'].dt.year
bikes['month'] = bikes['timestamp'].dt.month
bikes['day'] = bikes['timestamp'].dt.day
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  datetime64[ns]
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  object
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  object
#  10  year          17414 non-null  int64
#  11  month         17414 non-null  int64
#  12  day           17414 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
bikes = pd.read_csv('C:/Users/Ebru/dataset/london_merged.csv')

# %%
missing =bikes.isna()
print(missing)
# Out:
#        timestamp    cnt     t1     t2    hum  wind_speed  weather_code  \
# 0          False  False  False  False  False       False         False
# 1          False  False  False  False  False       False         False
# 2          False  False  False  False  False       False         False
# 3          False  False  False  False  False       False         False
# 4          False  False  False  False  False       False         False
# ...          ...    ...    ...    ...    ...         ...           ...
# 17409      False  False  False  False  False       False         False
# 17410      False  False  False  False  False       False         False
# 17411      False  False  False  False  False       False         False
# 17412      False  False  False  False  False       False         False
# 17413      False  False  False  False  False       False         False
#
#        is_holiday  is_weekend  season   year  month    day
# ...

# %%
weather_dict = {
    '1.0' : 'Clear',
    '2.0' : 'Scattered clouds',
    '3.0' : 'Broken clouds',
    '4.0' : 'Cloudy',
    '7.0' : 'Rain',
    '10.0' : 'Rain with thunderstorm',
    '26.0' : 'Snowfall'
}

# %%
bikes.weather_code = bikes.weather_code.astype('str')
bikes.weather_code = bikes.weather_code.map(weather_dict)

# %%
bikes
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5
# ...                    ...   ...  ...  ...    ...         ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0
#
#            weather_code  is_holiday  is_weekend  season
# 0         Broken clouds         0.0         1.0     3.0
# 1                 Clear         0.0         1.0     3.0
# ...

# %%
season_dict= {
    '0.0': 'spring',
    '1.0': 'summer',
    '2.0': 'autumn',
    '3.0': 'winter'
}

# %%
bikes.season = bikes.season.astype('str')
bikes.season =bikes.season.map(season_dict)

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  object
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
A=bikes['season'].value_counts()

# %%
A
# Out:
# spring    4394
# summer    4387
# winter    4330
# autumn    4303
# Name: season, dtype: int64

# %%
bikes['season'].unique()
# Out:
# array(['winter', 'spring', 'summer', 'autumn'], dtype=object)

# %%
plt.pie(A,labels=['winter', 'spring', 'summer', 'autumn'], colors=['blue', 'Yellow', 'Orange', 'lime'], startangle=50, shadow=False,
        radius=2, explode=(0.1,0.1,0.1,0.1), autopct='%1.2f%%', pctdistance=0.75)

circle= plt.Circle((0,0),1,color='white')
c=plt.gcf()

c.gca().add_artist(circle)

plt.title("Bike usage per seasons")
plt.show()

# %%
bikes.weather_code.nunique()
# Out:
# 7

# %%
bikes.weather_code.unique()
# Out:
# array(['Broken clouds', 'Clear', 'Cloudy', 'Rain', 'Scattered clouds',
#        'Snowfall', 'Rain with thunderstorm'], dtype=object)

# %%
num=bikes.weather_code.value_counts()
s = num.astype(int)
s.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 7 entries, Clear to Rain with thunderstorm
# Series name: weather_code
# Non-Null Count  Dtype
# --------------  -----
# 7 non-null      int32
# dtypes: int32(1)
# memory usage: 84.0+ bytes

# %%
import seaborn as sns
bikes.weather_code.value_counts(ascending=True)
# Out:
# Rain with thunderstorm      14
# Snowfall                    60
# Cloudy                    1464
# Rain                      2141
# Broken clouds             3551
# Scattered clouds          4034
# Clear                     6150
# Name: weather_code, dtype: int64

# %%
plt.figure(figsize=(2,7))
sns.countplot(bikes['hum']);

plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.show()

# %%
withgroup=bikes.groupby('weather_code')['cnt'].sum()
withgroup.plot(kind='bar')
plt.title("Total count by weather")
plt.xlabel("Weather")
plt.ylabel("Count")
plt.show()

# %%
bikes.columns
weekendornot=bikes.groupby('is_weekend')['cnt'].sum()
weekendornot.plot(kind='bar',color='pink')
# Out:
# <Axes: xlabel='is_weekend'>

# %%
plt.scatter(x='is_weekend',y='cnt', data=bikes)

# %%
df=sns.load_dataset('tips')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
plt.scatter(x='tip',y='total_bill', data=df)

# %%
bikes
# Out:
#                 timestamp   cnt   t1   t2    hum  wind_speed  \
# 0     2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0
# 1     2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0
# 2     2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0
# 3     2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0
# 4     2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5
# ...                   ...   ...  ...  ...    ...         ...
# 17409 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0
# 17410 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0
# 17411 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0
# 17412 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0
# 17413 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0
#
#            weather_code  is_holiday  is_weekend  season  year  month  day
# 0         Broken clouds         0.0         1.0  winter  2015      1    4
# 1                 Clear         0.0         1.0  winter  2015      1    4
# ...

# %%
bikes['weather_code'].unique()
# Out:
# array(['Broken clouds', 'Clear', 'Cloudy', 'Rain', 'Scattered clouds',
#        'Snowfall', 'Rain with thunderstorm'], dtype=object)

# %%
bikes.columns = bikes.columns.str.upper()

# %%
bikes.columns = bikes.columns.str.lower()
bikes
# Out:
#                 timestamp   cnt   t1   t2    hum  wind_speed  \
# 0     2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0
# 1     2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0
# 2     2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0
# 3     2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0
# 4     2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5
# ...                   ...   ...  ...  ...    ...         ...
# 17409 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0
# 17410 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0
# 17411 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0
# 17412 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0
# 17413 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0
#
#            weather_code  is_holiday  is_weekend  season  year  month  day
# 0         Broken clouds         0.0         1.0  winter  2015      1    4
# 1                 Clear         0.0         1.0  winter  2015      1    4
# ...

# %%
bikes
# Out:
#                 timestamp   cnt   t1   t2    hum  wind_speed  \
# 0     2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0
# 1     2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0
# 2     2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0
# 3     2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0
# 4     2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5
# ...                   ...   ...  ...  ...    ...         ...
# 17409 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0
# 17410 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0
# 17411 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0
# 17412 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0
# 17413 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0
#
#            weather_code  is_holiday  is_weekend  season  year  month  day
# 0         Broken clouds         0.0         1.0  winter  2015      1    4
# 1                 Clear         0.0         1.0  winter  2015      1    4
# ...
